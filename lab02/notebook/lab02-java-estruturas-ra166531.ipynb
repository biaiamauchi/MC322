// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
float s = 200;
int n = 5; 
float j = 1;
for (int i = 1; i <= n; i++){
    String resultado = String.format("%.2f", s);
    System.out.println("Valor da parcela " + i + ": " + resultado);
    s *= (1 + (j / 100));
}
// Out:
// Valor da parcela 1: 200.00
// Valor da parcela 2: 202.00
// Valor da parcela 3: 204.02
// Valor da parcela 4: 206.06
// Valor da parcela 5: 208.12
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Parcelas{
    static float proximaParcela(float s, float j){
        float preco;
        preco = s + (s * (j/100));
        return preco;
    }
};
// Out:
// com.twosigma.beaker.javash.bkr2852a88b.Parcelas

// %%
float s = 200;
int n = 5; 
float j = 1;
for (int i = 1; i <= n; i++){
    String resultado = String.format("%.2f", s);
    System.out.println("Valor da parcela " + i + ": " + resultado);
    s = Parcelas.proximaParcela(s, j);
}
// Out:
// Valor da parcela 1: 200.00
// Valor da parcela 2: 202.00
// Valor da parcela 3: 204.02
// Valor da parcela 4: 206.06
// Valor da parcela 5: 208.12
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
import java.util.Random;
Random random = new Random();
int numero = random.nextInt(9999);
System.out.println("Número inicial: " + numero);
String binario_invertido = "";
while (numero > 0){
    binario_invertido += Integer.toString(numero%2);
    numero = numero/2;
}
String binario_em_ordem = new StringBuilder(binario_invertido).reverse().toString();
System.out.println("Número convertido para binário: " + binario_em_ordem);
// Out:
// Número inicial: 2619
// Número convertido para binário: 101000111011
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Genetica {
    static String transcricao(String DNA){
        String RNA = "";
        for (int i=0; i<DNA.length(); i++) {
            char c = DNA.charAt(i);
            if (c == 'A'){
                RNA += 'T';
            } else if (c == 'T'){
                RNA += 'A';
            } else if (c == 'C'){
                RNA += 'G';
            } else if (c == 'G'){
                RNA += 'C';
            }
        }
        return RNA;
    }
};
// Out:
// com.twosigma.beaker.javash.bkr2852a88b.Genetica

// %%
String DNA = "ATTACGCGCAAAC";
System.out.println("DNA: " + DNA);
String RNA = Genetica.transcricao(DNA);
System.out.println("RNA: " + RNA);
// Out:
// DNA: ATTACGCGCAAAC
// RNA: TAATGCGCGTTTG
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

Random aleatorio = new Random();
int salarios[] = new int[51];
double media = 0;
int contagem = 0;
for (int i = 1; i <= 50; i++){
    int valor = aleatorio.nextInt((15000 - 2500) + 1) + 2500;
    salarios[i] = valor;
    System.out.println("Valor do salário " + i + ": " + valor);
    media += valor;
}
media = media/50;
for (int j = 1; j <= 50; j++){
    if (salarios[j] > media){
        contagem += 1;
    }
}
System.out.println("Média dos salários: R$" + media);
System.out.println("Número de funcionários com salário maior que a média: " + contagem);
// Out:
// Valor do salário 1: 5554
// Valor do salário 2: 13387
// Valor do salário 3: 4402
// Valor do salário 4: 2668
// Valor do salário 5: 9375
// Valor do salário 6: 3135
// Valor do salário 7: 13847
// Valor do salário 8: 3313
// Valor do salário 9: 14314
// Valor do salário 10: 14919
// Valor do salário 11: 5295
// Valor do salário 12: 4314
// Valor do salário 13: 8292
// Valor do salário 14: 10386
// Valor do salário 15: 11024
// Valor do salário 16: 12428
// Valor do salário 17: 11734
// Valor do salário 18: 5191
// Valor do salário 19: 6544
// Valor do salário 20: 8667
// Valor do salário 21: 5245
// Valor do salário 22: 5120
// Valor do salário 23: 4179
// Valor do salário 24: 12103
// Valor do salário 25: 12995
// Valor do salário 26: 11534
// Valor do salário 27: 14672
// Valor do salário 28: 9982
// Valor do salário 29: 13931
// Valor do salário 30: 10975
// Valor do salário 31: 10186
// Valor do salário 32: 5136
// Valor do salário 33: 12826
// Valor do salário 34: 4622
// Valor do salário 35: 11346
// Valor do salário 36: 6167
// Valor do salário 37: 14875
// Valor do salário 38: 6911
// Valor do salário 39: 8122
// Valor do salário 40: 12325
// Valor do salário 41: 2851
// Valor do salário 42: 7947
// Valor do salário 43: 6244
// Valor do salário 44: 6599
// Valor do salário 45: 7735
// Valor do salário 46: 13883
// Valor do salário 47: 13612
// Valor do salário 48: 10572
// Valor do salário 49: 11479
// Valor do salário 50: 2606
// Média dos salários: R$8911.38
// Número de funcionários com salário maior que a média: 25
// null
